# %% [markdown]
# # Volume Prediction from Suction Reservoir Images
#
# ## Goal
# Evaluate how well a CNN trained on final reservoir images can predict liquid volume,
# and analyze model behavior, bias, and error structure without retraining.
#
# ## Key idea
# Training and analysis are decoupled:
# - Training is done once in a standalone script.
# - This notebook focuses on interpretation and diagnostics.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import loadmat
from sklearn.metrics import mean_squared_error
# Out:
# --------------------------------------------------------------------------
# NameError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 clear; clc;
#       3 get_ipython().run_line_magic('', 'Load trained network')
#       4 load('netTrained.mat')   % netTrained
#
# NameError: name 'clear' is not defined

# %%
## Dataset sanity check

Before evaluating the model, we verify that the physical labels are consistent
with experimental parameters such as number of drops.
